# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\yusuf\Desktop\DataScience Journey\python refresh\Day5\netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#      show_id     type                                              title  \
# 3598   s3599  TV Show                                DC Super Hero Girls
# 7470   s7471    Movie                                       Miss Stevens
# 6934   s6935    Movie                          Harry Benson: Shoot First
# 6516   s6517    Movie                                            Colonia
# 6253   s6254  TV Show                               Battlefield Recovery
# 3438   s3439    Movie                                              After
# 2664   s2665  TV Show      ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 2384   s2385    Movie  The Show Must Go On: The Queen + Adam Lambert ...
# 3498   s3499    Movie            Do Paise Ki Dhoop Chaar Aane Ki Baarish
# 7263   s7264    Movie                                          Lady-Like
#
#                         director  \
# 3598                         NaN
# 7470                  Julia Hart
# 6934  Justin Bare, Matthew Miele
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df[2:5]
# Out:
#   show_id     type                  title         director  \
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 3                                                NaN     NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
# ...

# %%
df[:]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.title
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
type(df['title'])
# Out:
# pandas.core.series.Series

# %%
df[['title','rating']]
# Out:
#                       title rating
# 0      Dick Johnson Is Dead  PG-13
# 1             Blood & Water  TV-MA
# 2                 Ganglands  TV-MA
# 3     Jailbirds New Orleans  TV-MA
# 4              Kota Factory  TV-MA
# ...                     ...    ...
# 8802                 Zodiac      R
# 8803            Zombie Dumb  TV-Y7
# 8804             Zombieland      R
# 8805                   Zoom     PG
# 8806                 Zubaan  TV-14
#
# [8807 rows x 2 columns]

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['release_year'].max()
# Out:
# 2021

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df[df.release_year>=2021]
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda              NaN
# 1696   s1697  TV Show               Polly Pocket              NaN
# 2920   s2921  TV Show              Love Is Blind              NaN
# 8437   s8438  TV Show     The Netflix Afterparty              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df.iloc[8437]
# Out:
# show_id                                                     s8438
# type                                                      TV Show
# title                                      The Netflix Afterparty
# director                                                      NaN
# cast                 David Spade, London Hughes, Fortune Feimster
# country                                             United States
# date_added                                        January 2, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                 1 Season
# listed_in               Stand-Up Comedy & Talk Shows, TV Comedies
# description     Hosts David Spade, Fortune Feimster and London...
# Name: 8437, dtype: object

# %%
df.loc[8437]
# Out:
# show_id                                                     s8438
# type                                                      TV Show
# title                                      The Netflix Afterparty
# director                                                      NaN
# cast                 David Spade, London Hughes, Fortune Feimster
# country                                             United States
# date_added                                        January 2, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                 1 Season
# listed_in               Stand-Up Comedy & Talk Shows, TV Comedies
# description     Hosts David Spade, Fortune Feimster and London...
# Name: 8437, dtype: object

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.isna().any()
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %%
df['director'].fillna('unknown',inplace=True)
df['country'].fillna('unknown',inplace=True)
df['rating'].fillna(df['rating'].mode()[0],inplace=True)
# Out:
# C:\Users\yusuf\AppData\Local\Temp\ipykernel_26568\2556237724.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna('unknown',inplace=True)
# C:\Users\yusuf\AppData\Local\Temp\ipykernel_26568\2556237724.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
print(df['rating'].mode()[0])
# Out:
# TV-MA

# %%
print(df.isna().any())
# Out:
# show_id         False
# type            False
# title           False
# director        False
# cast             True
# country         False
# date_added       True
# release_year    False
# rating          False
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                                NaN        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
movie_vs_TVShow=df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
top5_countries=df['country'].value_counts().head(5)
# Out:
# country
# United States     2818
# India              972
# unknown            831
# United Kingdom     419
# Japan              245
# Name: count, dtype: int64

# %%
top10_directors =df['director'].value_counts().head(10)

# %%
year_with_most_releases=df.groupby('release_year')['show_id'].count()[
    df.groupby('release_year')['show_id'].count() ==
    df.groupby('release_year')['show_id'].count().max()
]
# Out:
# release_year
# 2018    1147
# Name: show_id, dtype: int64

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknown
# 4      s5  TV Show           Kota Factory          unknown
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                                NaN        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
avg_duration = (
    df[df['type'] == 'Movie']['duration']
    .str.extract(r'(\d+)')      # extract numbers only
    .astype(float)
    .mean()
)
print(avg_duration)
# Out:
# 0    99.577187
# dtype: float64

# %%
movie_ratings = df[df['type'] == 'Movie']['rating'].value_counts()
most_common = movie_ratings[movie_ratings == movie_ratings.max()]

most_common
# Out:
# rating
# TV-MA    2064
# Name: count, dtype: int64

# %%
movies_per_year=df[df['type']=='Movie'].groupby('release_year')['show_id'].count()
# Out:
# release_year
# 1942      2
# 1943      3
# 1944      3
# 1945      3
# 1946      1
#        ...
# 2017    767
# 2018    767
# 2019    633
# 2020    517
# 2021    277
# Name: show_id, Length: 73, dtype: int64

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df[df['country']=='United States'].sort_values('release_year',ascending=False)['title'].head(5)
# Out:
# 520     I Think You Should Leave with Tim Robinson
# 8437                        The Netflix Afterparty
# 40          He-Man and the Masters of the Universe
# 15                               Dear White People
# 9                                     The Starling
# Name: title, dtype: object

# %%
def recommend_by_country(country_name):
    return (
        df[df['country'] == country_name]
        .sort_values('release_year', ascending=False)
        ['title']
        .head(5)
    )

# %%
recommend_by_country('United States')
# Out:
# 520     I Think You Should Leave with Tim Robinson
# 8437                        The Netflix Afterparty
# 40          He-Man and the Masters of the Universe
# 15                               Dear White People
# 9                                     The Starling
# Name: title, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          7982 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['country'].value_counts().head(5)
# Out:
# country
# United States     2818
# India              972
# unknown            831
# United Kingdom     419
# Japan              245
# Name: count, dtype: int64
